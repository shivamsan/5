# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout
# Out:
# WARNING:tensorflow:From c:\Users\iamsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
train_df = pd.read_csv('Google_Stock_Price_Train.csv')
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   object
#  1   Open    1258 non-null   float64
#  2   High    1258 non-null   float64
#  3   Low     1258 non-null   float64
#  4   Close   1258 non-null   object
#  5   Volume  1258 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 59.1+ KB

# %%
test_df = pd.read_csv('Google_Stock_Price_Test.csv')
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Open    20 non-null     float64
#  2   High    20 non-null     float64
#  3   Low     20 non-null     float64
#  4   Close   20 non-null     float64
#  5   Volume  20 non-null     object
# dtypes: float64(4), object(2)
# memory usage: 1.1+ KB

# %%
train = train_df.loc[:,["Open"]].values
train.shape
# Out:
# (1258, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
train_scaled = scaler.fit_transform(train)

# %%
plt.plot(train_scaled)
plt.ylabel("Standardized Values")
plt.xlabel("Time->")
plt.show()

# %%
x_train = []
y_train = []
time = 60
for i in range(60,train_scaled.shape[0]):
    x_train.append(train_scaled[i-60:i,0])
    y_train.append(train_scaled[i,0])
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
x_train.shape,y_train.shape
# Out:
# ((1198, 60), (1198,))

# %%
x_train = np.reshape(x_train,newshape=(x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (1198, 60, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN,Dropout

# %%
model = Sequential()

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True, input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50))
model.add(Dropout(0.2))

model.add(Dense(units=1))

model.compile(optimizer='adam',loss='mse')
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\iamsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\iamsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 60, 50)            2600
#
#  dropout (Dropout)           (None, 60, 50)            0
#
#  simple_rnn_1 (SimpleRNN)    (None, 60, 50)            5050
#
#  dropout_1 (Dropout)         (None, 60, 50)            0
#
#  simple_rnn_2 (SimpleRNN)    (None, 60, 50)            5050
#
#  dropout_2 (Dropout)         (None, 60, 50)            0
#
#  simple_rnn_3 (SimpleRNN)    (None, 50)                5050
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 17801 (69.54 KB)
# Trainable params: 17801 (69.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x_train,y_train,epochs=100,batch_size=30,validation_split=0.05)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\iamsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 38/38 [==============================] - 4s 31ms/step - loss: 0.4442 - val_loss: 0.0017
# Epoch 2/100
# 38/38 [==============================] - 1s 21ms/step - loss: 0.2715 - val_loss: 0.0122
# Epoch 3/100
# 38/38 [==============================] - 1s 20ms/step - loss: 0.2142 - val_loss: 0.0165
# Epoch 4/100
# 38/38 [==============================] - 1s 21ms/step - loss: 0.1586 - val_loss: 8.3323e-04
# Epoch 5/100
# 38/38 [==============================] - 1s 21ms/step - loss: 0.1247 - val_loss: 0.0045
# Epoch 6/100
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0916 - val_loss: 0.0343
# Epoch 7/100
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0786 - val_loss: 0.0492
# Epoch 8/100
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0636 - val_loss: 0.0340
# Epoch 9/100
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0541 - val_loss: 0.0049
# Epoch 10/100
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0490 - val_loss: 0.0217
# Epoch 11/100
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0416 - val_loss: 0.0195
# Epoch 12/100
# 38/38 [==============================] - 1s 22ms/step - loss: 0.
100
# 38/38 [==============================] - 2s 49ms/step - loss: 0.0026 - val_loss: 6.1671e-04
# Epoch 67/100
# 38/38 [==============================] - 2s 48ms/step - loss: 0.0028 - val_loss: 5.9901e-04
# Epoch 68/100
# 38/38 [==============================] - 2s 48ms/step - loss: 0.0027 - val_loss: 4.7205e-04
# Epoch 69/100
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0031 - val_loss: 0.0022
# Epoch 70/100
# 38/38 [==============================] - 2s 49ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 71/100
# 38/38 [==============================] - 2s 48ms/step - loss: 0.0028 - val_loss: 6.5312e-04
# Epoch 72/100
# 38/38 [==============================] - 2s 49ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 73/100
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0027 - val_loss: 4.9016e-04
# Epoch 74/100
# 38/38 [==============================] - 2s 50ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 75/100
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0028 - val_loss: 0.0019
# Epoch 76/100
# 38/38 [==============================] - 2s 49ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 77/100
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0026 - val_loss: 4.6113e-04
# Epoch 78/100
# 38/38 [==============================] - 2s 50ms/step - loss: 0.0022 - val_loss: 4.6293e-04
# Epoch 79/100
# 38/38 [==============================] - 2s 48ms/step - loss: 0.0022 - val_loss: 9.5121e-04
# Epoch 80/100
# 38/38 [==============================] - 2s 49ms/step - loss: 0.0021 - val_loss: 8.6548e-04
# Epoch 81/100
# 38/38 [==============================] - 2s 49ms/step - loss: 0.0024 - val_loss: 5.5576e-04
# Epoch 82/100
# 38/38 [==============================] - 2s 49ms/step - loss: 0.0021 - val_loss: 5.9468e-04
# Epoch 83/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0021 - val_loss: 4.4150e-04
# Epoch 84/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0022 - val_loss: 6.9823e-04
# Epoch 85/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0020 - val_loss: 9.6308e-04
# Epoch 86/100
# 38/38 [==============================] - 1s 30ms/step - loss: 0.0022 - val_loss: 4.3406e-04
# Epoch 87/100
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0021 - val_loss: 7.2366e-04
# Epoch 88/100
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0021 - val_loss: 4.3151e-04
# Epoch 89/100
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0023 - val_loss: 7.3826e-04
# Epoch 90/100
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 91/100
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0018 - val_loss: 4.4200e-04
# Epoch 92/100
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0019 - val_loss: 4.8188e-04
# Epoch 93/100
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0020 - val_loss: 4.1565e-04
# Epoch 94/100
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0019 - val_loss: 4.9365e-04
# Epoch 95/100
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 96/100
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0019 - val_loss: 4.1565e-04
# Epoch 97/100
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0019 - val_loss: 4.8750e-04
# Epoch 98/100
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0020 - val_loss: 5.2909e-04
# Epoch 99/100
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0018 - val_loss: 4.9373e-04
# Epoch 100/100
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0018 - val_loss: 0.0013

# %%
data = pd.concat((train_df['Open'],test_df['Open']),axis=0)

# %%
test_input = data.iloc[len(data) - len(test_df) - time : ].values
test_input.shape
# Out:
# (80,)

# %%
test_input = test_input.reshape(-1,1)
test_input.shape
# Out:
# (80, 1)

# %%
test_scaled = scaler.transform(test_input)

# %%
x_test = []
for i in range(time,test_scaled.shape[0]):
    x_test.append(test_scaled[i - time: i,0 ])
x_test = np.array(x_test)
x_test.shape
# Out:
# (20, 60)

# %%
x_test = np.reshape(x_test,newshape=(x_test.shape[0],x_test.shape[1],1))
x_test.shape
# Out:
# (20, 60, 1)

# %%
y_test = test_df.loc[:,"Open"].values

# %%
y_pred = model.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 365ms/step

# %%
y_pred = scaler.inverse_transform(y_pred)

# %%
output = model.evaluate(x=x_test,y=y_test)
# Out:
# 1/1 [==============================] - 0s 448ms/step - loss: 650696.5625

# %%
plt.plot(y_test, color = 'red', label = 'Real price')
plt.plot(y_pred, color = 'blue', label = 'Predicted price')

plt.title('Google Stock price prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
